# %% [markdown]
# <a href="https://colab.research.google.com/github/hitanshi08/OasisInfobyte/blob/main/Unemployment_Analysis_for_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Unemployment in India.csv')

# %%
# Display the first few rows of the dataset to understand its structure
print(data.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
# Summary statistics
print(data.describe())
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
print(data.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
# Data Cleaning: Remove leading and trailing whitespaces from column names
df.columns = df.columns.str.strip()

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Data Exploration: Visualize the unemployment rate over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Estimated Unemployment Rate (%)', data=df, hue='Region')
plt.title('Unemployment Rate Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.show()

# %%
# Distribution of Unemployment Rate
plt.figure(figsize=(10, 6))
sns.histplot(data[' Estimated Unemployment Rate (%)'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of Unemployment Rate(%)')
plt.xlabel(' Estimated Unemployment Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Data Analysis: Calculate and visualize the average unemployment rate by region
average_unemployment_by_region = df.groupby('Region')['Estimated Unemployment Rate (%)'].mean().sort_values()

# %%
plt.figure(figsize=(10, 6))
average_unemployment_by_region.plot(kind='barh', color='skyblue')
plt.title('Average Unemployment Rate by Region')
plt.xlabel('Average Estimated Unemployment Rate (%)')
plt.ylabel('Region')
plt.show()
